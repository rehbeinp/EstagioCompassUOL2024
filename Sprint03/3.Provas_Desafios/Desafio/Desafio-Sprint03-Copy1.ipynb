# %% [markdown]
# # Desafio
# Ler o arquivo e gerar gráficos de anélise.

# %% [markdown]
# ### Imprimindo a tabela:

# %%
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')

# %%
dados
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ### Removendo linhas dúplicadas:

# %%
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
dados_sem_repeticao
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ### Ordenando apps pela categoria "Installs":

# %%
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
dados_ordenados=dados_sem_repeticao.sort_values(by='Installs', ascending=False)
dados_ordenados
# Out:
#                             App        Category  Rating   Reviews  \
# 2546              Facebook Lite          SOCIAL     4.3   8606259
# 1722             My Talking Tom            GAME     4.5  14891223
# 3235           Google Translate           TOOLS     4.4   5745093
# 1885                        Pou            GAME     4.3  10486018
# 3870                   Snapchat          SOCIAL     4.0  17000166
# ...                         ...             ...     ...       ...
# 9719               EP Cook Book         MEDICAL     NaN         0
# 8871     Test Application DT 02  ART_AND_DESIGN     NaN         0
# 9917                Eu Sou Rico         FINANCE     NaN         0
# 8081                 CX Network        BUSINESS     NaN         0
# 9148  Command & Conquer: Rivals          FAMILY     NaN         0
#
#                     Size      Installs  Type    Price Content Rating  \
# 2546  Varies with device  500,000,000+  Free        0           Teen
# ...

# %% [markdown]
# ### Selecionando top 5 apps por número de instalação:

# %%
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
dados_ordenados=dados_sem_repeticao.sort_values(by='Installs', ascending=False)
top_cinco = dados_ordenados[["App", "Installs"]].head()
top_cinco
# Out:
#                    App      Installs
# 2546     Facebook Lite  500,000,000+
# 1722    My Talking Tom  500,000,000+
# 3235  Google Translate  500,000,000+
# 1885               Pou  500,000,000+
# 3870          Snapchat  500,000,000+

# %% [markdown]
# ### Gráfico contendo os 5 apps por número de instalação:

# %%
import matplotlib.pyplot as plt
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
dados_ordenados=dados_sem_repeticao.sort_values(by='Installs', ascending=False)
top_cinco = dados_ordenados[["App", "Installs"]].head()
app=top_cinco["App"]
inst=top_cinco["Installs"]
instal=[]
for n in inst:
    str(n)
    n=n.strip("+")
    n=n.replace(",","")
    n=float(n)
    instal.append(n)
app=list(app)
plt.xticks(instal)
plt.barh(app,instal,  color="blue")
barWidth=0.10
plt.ylabel('Aplicativos')
plt.xlabel("Número de instalaçõs(milhões)")
plt.title("Cinco aplicativos com mais instalações")
barhWidth=0.25
# Out:
#                    App      Installs
# 2546     Facebook Lite  500,000,000+
# 1722    My Talking Tom  500,000,000+
# 3235  Google Translate  500,000,000+
# 1885               Pou  500,000,000+
# 3870          Snapchat  500,000,000+

# %% [markdown]
# ### Categorias de apps existentes ordenados de acordo com a frequência:

# %%
import matplotlib.pyplot as plt
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
dados_sem_repeticao=dados_sem_repeticao.drop_duplicates("App")
catego=dados_sem_repeticao[["Category",]]
catego=catego.value_counts(normalize=True)
freq=catego
catego = catego.reset_index(level='Category')
cat=list(catego['Category'])
freq=list(freq)
labels=cat
sizes=freq
plt.rcParams['xtick.labelsize'] = 5
fg1, ax1=plt.subplots()
ax1.pie(sizes, labels=labels,startangle=5, shadow=True, radius=10.5)
ax1.axis("equal")
plt.show()

# %% [markdown]
# ### Aplicativo mais caro do dataset:

# %%
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
valor_ordenados=dados_sem_repeticao[["App","Type","Price"]]
valor_ordenados=valor_ordenados[["App","Type","Price"]].loc[valor_ordenados['Type'] == 'Paid']
valor_ordenados['Price'] = valor_ordenados['Price'].str.replace('$','').astype(float)
valor_ordenados=valor_ordenados.sort_values(by='Price', ascending=False)
app_mais_caro=valor_ordenados.head(1)
app_mais_caro
# Out:
#                            App  Type  Price
# 4367  I'm Rich - Trump Edition  Paid  400.0

# %% [markdown]
# ### Apps classificados como 'Mature 17+':

# %%
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
maiores=dados_sem_repeticao[["App","Content Rating"]].loc[dados_sem_repeticao['Content Rating'] == 'Mature 17+']
maiores=maiores.drop_duplicates("App")
maiores=maiores["Content Rating"]
maiores=maiores.value_counts()
i=0
for n in maiores:
    i=maiores[0]
print(f"O número de apps com Mature 17+ é: {i}.")
# Out:
# O número de apps com Mature 17+ é: 393.
# C:\Users\teste\AppData\Local\Temp\ipykernel_10504\1000430877.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   i=maiores[0]

# %% [markdown]
# ### Top 10 Apps por número de reviews, ordenados de forma decrescente:

# %%
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
avalia=dados_sem_repeticao[["App","Reviews"]]
avalia=avalia.sort_values(by='Reviews', ascending=False)
avalia=avalia.drop_duplicates("App")
avalia=avalia.head(10)
avalia
# Out:
#                                                     App   Reviews
# 2544                                           Facebook  78158306
# 336                                  WhatsApp Messenger  69119316
# 2604                                          Instagram  66577446
# 382            Messenger – Text and Video Chat for Free  56646578
# 1879                                     Clash of Clans  44893888
# 4005            Clean Master- Space Cleaner & Antivirus  42916526
# 1872                                     Subway Surfers  27725352
# 3665                                            YouTube  25655305
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...  24900999
# 1878                                       Clash Royale  23136735

# %% [markdown]
# ### Calculo 1 (Forma de valor): Quantidade do tipo de avaliação no dataset:

# %%
import matplotlib.pyplot as plt
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
dados_sem_repeticao=dados_sem_repeticao.drop_duplicates("App")
avalia=dados_sem_repeticao[["Rating"]]
avalia=avalia.value_counts(normalize=False)
avalia
# Out:
# Rating
# 4.3       897
# 4.4       895
# 4.5       848
# 4.2       810
# 4.6       683
# 4.1       621
# 4.0       513
# 4.7       442
# 3.9       359
# 3.8       286
# 5.0       271
# 3.7       224
# 4.8       221
# 3.6       167
# 3.5       156
# 3.4       126
# 3.3       100
# 4.9        85
# 3.0        81
# 3.1        69
# 3.2        63
# 2.9        45
# 2.8        40
# 2.6        24
# 2.7        23
# 2.3        20
# 2.5        20
# 2.4        19
# 1.0        16
# 2.2        14
# 2.0        12
# 1.9        12
# 2.1         8
# 1.8         8
# 1.7         8
# 1.6         4
# 1.5         3
# 1.4         3
# 1.2         1
# Name: count, dtype: int64

# %% [markdown]
# #### Gráfico:

# %%
import matplotlib.pyplot as plt
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
dados_sem_repeticao=dados_sem_repeticao.drop_duplicates("App")
avalia=dados_sem_repeticao[["Rating"]]
avalia=avalia.value_counts(normalize=True)
freq=avalia
avalia = avalia.reset_index(level='Rating')

scatter_plot=avalia.plot.scatter(x='proportion',y='Rating')
scatter_plot.plot()
plt.show()

# %% [markdown]
# ### Calculo 2(Forma de lista): Ordenação do Top 5 Genres por tamanho decrescente:

# %%
import pandas as pd
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
dados_sem_repeticao=dados_sem_repeticao.drop_duplicates("App")
generos=dados_sem_repeticao[["Genres"]]
generos=generos.value_counts()
generos=generos.sort_values(ascending=False).head(10)
generos
# Out:
# Genres
# Tools              826
# Entertainment      561
# Education          510
# Business           420
# Medical            395
# Personalization    376
# Productivity       374
# Lifestyle          368
# Finance            345
# Sports             331
# Name: count, dtype: int64

# %% [markdown]
# #### Gráfico:

# %%
import pandas as pd
import matplotlib.pyplot as plt
dados=pd.read_csv('./googleplaystore.csv',encoding='utf-8', delimiter=',')
dados_sem_repeticao=dados.drop_duplicates()
dados_sem_repeticao=dados_sem_repeticao.drop_duplicates("App")
generos=dados_sem_repeticao[["Genres"]]
generos=generos.value_counts()

generos=generos.sort_values(ascending=False).head(5)
generos = generos.reset_index(level='Genres')
generos
plt.rcParams['xtick.labelsize'] = 8
generos.plot( 'Genres' , 'count',title = "Quantidade de aplicativos por gênero (5 mais frequentes)" )
# Out:
# <Axes: title={'center': 'Quantidade de aplicativos por gênero (5 mais frequentes)'}, xlabel='Genres'>
